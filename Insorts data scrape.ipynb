# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
USER_AGENT = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

insort_url ='https://inshorts.com/en/read'

response = requests.get(insort_url, headers=USER_AGENT)
response.raise_for_status()
html=response.text

soup = BeautifulSoup(html, 'html.parser')
hedline = soup.find_all('span', attrs={'itemprop': 'headline'})
# print(result_block)
news_body = soup.find_all('div', attrs={'itemprop': 'articleBody'})


for i,j in zip(hedline,news_body):
    print(i.text,":\n",j.text,"\n")
    
    
df = pd.DataFrame({"Headline":hedline,"body":body})
# Out:
# Rakesh, Sarang Wadhawan held in PMC Bank case, ₹3,500cr assets attached :
#  The Mumbai Police on Thursday arrested Rakesh Kumar Wadhawan and Sarang Wadhawan, the promoters of bankrupt realty firm HDIL, in the PMC Bank case and attached assets worth ₹3,500 crore of HDIL. The FIR alleges a wrongful loss of ₹4,355 crore to the bank. PMC allegedly created more than 21,000 fictitious accounts to hide loans it made to HDIL.
#
# Guj women run 53 km backwards in 13 hrs, seek Guinness World Record :
#  Two women from Gujarat ran 53 kilometres backwards in 13 hours on the 150th anniversary of Mahatma Gandhi. The sisters-in-law seek to secure a place in the Guinness World Record and have sent footage of their run to the organisation. "Our aim was to motivate women to come forward and showcase their skills," the duo said.
#
# Kohli keeps dressing room door open for Rohit after he gets out on 176 :
# ...
